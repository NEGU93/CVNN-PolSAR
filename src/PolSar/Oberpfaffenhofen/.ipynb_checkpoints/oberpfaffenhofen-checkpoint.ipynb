# %% [markdown]
# # PolSAR Oberpfaffenhofen example
#
# - Download the dataset from [esa official website](https://earth.esa.int/web/polsarpro/data-sources/sample-datasets).
# - Ground truth can be found at this [github repository](https://github.com/fudanxu/CV-CNN/blob/master/Label_Germany.mat).

# %% [markdown]
# First we open the dataset

# %%
from pathlib import Path
import scipy.io
import numpy as np
import spectral.io.envi as envi
from cvnn.utils import standarize, randomize

raw_labels = scipy.io.loadmat('/media/barrachina/data/datasets/PolSar/Oberpfaffenhofen/Label_Germany.mat')['label']
path = Path('/media/barrachina/data/datasets/PolSar/Oberpfaffenhofen/ESAR_Oberpfaffenhofen_T6/Master_Track_Slave_Track/T6')
T = np.zeros(raw_labels.shape + (21,), dtype=complex)

T[:, :, 0] = standarize(envi.open(path / 'T11.bin.hdr', path / 'T11.bin').read_band(0))
T[:, :, 1] = standarize(envi.open(path / 'T22.bin.hdr', path / 'T22.bin').read_band(0))
T[:, :, 2] = standarize(envi.open(path / 'T33.bin.hdr', path / 'T33.bin').read_band(0))
T[:, :, 3] = standarize(envi.open(path / 'T44.bin.hdr', path / 'T44.bin').read_band(0))
T[:, :, 4] = standarize(envi.open(path / 'T55.bin.hdr', path / 'T55.bin').read_band(0))
T[:, :, 5] = standarize(envi.open(path / 'T66.bin.hdr', path / 'T66.bin').read_band(0))

T[:, :, 6] = standarize(envi.open(path / 'T12_real.bin.hdr', path / 'T12_real.bin').read_band(0) + \
                        1j * envi.open(path / 'T12_imag.bin.hdr', path / 'T12_imag.bin').read_band(0))
T[:, :, 7] = standarize(envi.open(path / 'T13_real.bin.hdr', path / 'T13_real.bin').read_band(0) + \
                        1j * envi.open(path / 'T13_imag.bin.hdr', path / 'T13_imag.bin').read_band(0))
T[:, :, 8] = standarize(envi.open(path / 'T14_real.bin.hdr', path / 'T14_real.bin').read_band(0) + \
                        1j * envi.open(path / 'T14_imag.bin.hdr', path / 'T14_imag.bin').read_band(0))
T[:, :, 9] = standarize(envi.open(path / 'T15_real.bin.hdr', path / 'T15_real.bin').read_band(0) + \
                        1j * envi.open(path / 'T15_imag.bin.hdr', path / 'T15_imag.bin').read_band(0))
T[:, :, 10] = standarize(envi.open(path / 'T16_real.bin.hdr', path / 'T16_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T16_imag.bin.hdr', path / 'T16_imag.bin').read_band(0))

T[:, :, 11] = standarize(envi.open(path / 'T23_real.bin.hdr', path / 'T23_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T23_imag.bin.hdr', path / 'T23_imag.bin').read_band(0))
T[:, :, 12] = standarize(envi.open(path / 'T24_real.bin.hdr', path / 'T24_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T24_imag.bin.hdr', path / 'T24_imag.bin').read_band(0))
T[:, :, 13] = standarize(envi.open(path / 'T25_real.bin.hdr', path / 'T25_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T25_imag.bin.hdr', path / 'T25_imag.bin').read_band(0))
T[:, :, 14] = standarize(envi.open(path / 'T26_real.bin.hdr', path / 'T26_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T26_imag.bin.hdr', path / 'T26_imag.bin').read_band(0))

T[:, :, 15] = standarize(envi.open(path / 'T34_real.bin.hdr', path / 'T34_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T34_imag.bin.hdr', path / 'T34_imag.bin').read_band(0))
T[:, :, 16] = standarize(envi.open(path / 'T35_real.bin.hdr', path / 'T35_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T35_imag.bin.hdr', path / 'T35_imag.bin').read_band(0))
T[:, :, 17] = standarize(envi.open(path / 'T36_real.bin.hdr', path / 'T36_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T36_imag.bin.hdr', path / 'T36_imag.bin').read_band(0))

T[:, :, 18] = standarize(envi.open(path / 'T45_real.bin.hdr', path / 'T45_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T45_imag.bin.hdr', path / 'T45_imag.bin').read_band(0))
T[:, :, 19] = standarize(envi.open(path / 'T46_real.bin.hdr', path / 'T46_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T46_imag.bin.hdr', path / 'T46_imag.bin').read_band(0))

T[:, :, 20] = standarize(envi.open(path / 'T56_real.bin.hdr', path / 'T56_real.bin').read_band(0) + \
                         1j * envi.open(path / 'T56_imag.bin.hdr', path / 'T56_imag.bin').read_band(0))

print("T shape " + str(T.shape) + "; labels shape " + str(raw_labels.shape))
# Out:
# T shape (1300, 1200, 21); labels shape (1300, 1200)

# %% [markdown]
# See the ground truth was correctly opened:

# %%
import matplotlib.pyplot as plt
import tikzplotlib

def show_ground_truth(labels, savefile=None):
    colors = np.array([
        [1, 0.349, 0.392],
        [0.086, 0.858, 0.576],
        [0.937, 0.917, 0.352]
    ])
    ground_truth = np.zeros(labels.shape + (3,), dtype=float)
    for i in range(labels.shape[0]):
        for j in range(labels.shape[1]):
            if labels[i, j] != 0:
                ground_truth[i, j] = colors[labels[i, j] - 1]
    plt.imshow(ground_truth)
    plt.show()
    if savefile is not None:
        plt.imsave(savefile + ".pdf", ground_truth)
        tikzplotlib.save(savefile + ".tex")
    
    
show_ground_truth(raw_labels)

# %% [markdown]
# Preprocess dataset

# %%
def remove_unlabeled(x, y):
    mask = y != 0
    return x[mask], y[mask]

T, labels = remove_unlabeled(T, raw_labels)    # Remove unlabaled pixels
labels -= 1                                    # map [1, 3] to [0, 2]

# %%
labels.shape
# Out:
# (1311618,)

# %% [markdown]
# Separate Test, Train and validation

# %%
from cvnn.dataset import Dataset

def separate_train_test(x, y, ratio=0.1):
    classes = set(y)
    x_ordered_database = []
    y_ordered_database = []
    for cls in classes:
        mask = y == cls
        x_ordered_database.append(x[mask])
        y_ordered_database.append(y[mask])
    len_train = int(y.shape[0]*ratio/len(classes))
    x_train = x_ordered_database[0][:len_train]
    x_test = x_ordered_database[0][len_train:]
    y_train = y_ordered_database[0][:len_train]
    y_test = y_ordered_database[0][len_train:]
    for i in range(len(y_ordered_database)):
        assert (y_ordered_database[i] == i).all()
        assert len(y_ordered_database[i]) == len(x_ordered_database[i])
        if i != 0:
            x_train = np.concatenate((x_train, x_ordered_database[i][:len_train]))
            x_test = np.concatenate((x_test, x_ordered_database[i][len_train:]))
            y_train = np.concatenate((y_train, y_ordered_database[i][:len_train]))
            y_test = np.concatenate((y_test, y_ordered_database[i][len_train:]))
    x_train, y_train = randomize(x_train, y_train)
    x_test, y_test = randomize(x_test, y_test)
    return x_train, y_train, x_test, y_test

T_rand, labels_rand = randomize(T, labels)
x_train, y_train, x_test, y_test = separate_train_test(T_rand, labels_rand, ratio=0.1)
x_train, y_train, x_val, y_val = separate_train_test(x_train, y_train, ratio=0.8)
y_train = Dataset.sparse_into_categorical(y_train)
y_test = Dataset.sparse_into_categorical(y_test)
y_val = Dataset.sparse_into_categorical(y_val)
dataset = Dataset(x_train.astype(np.complex64), y_train, dataset_name='Oberpfaffenhofen')

print("Sizes:\n\t- Train shape: " + str(x_train.shape) + "\n\t- Test shape: " + str(x_test.shape) + "\n\t- Validation shape: " + str(x_val.shape))
# Out:
# Sizes:
# 	- Train shape: (104928, 21)
# 	- Test shape: (1180458, 21)
# 	- Validation shape: (26232, 21)

# %% [markdown]
# For training we use the same number of class examples for train and validation set

# %%
def get_number_of_each_class(x, name):
    x = np.array(x)
    x = Dataset.categorical_to_sparse(x)
    print(name + " set")
    for cls in range(min(x), max(x)+1):
        print("\t" + str(np.sum(x == cls)) + " examples of class " + str(cls))
        
        
get_number_of_each_class(y_train, "Train")
get_number_of_each_class(y_test, "Test")
get_number_of_each_class(y_val, "Validation")
# Out:
# Train set
# 	34976 examples of class 0
# 	34976 examples of class 1
# 	34976 examples of class 2
# Test set
# 	284331 examples of class 0
# 	202953 examples of class 1
# 	693174 examples of class 2
# Validation set
# 	8744 examples of class 0
# 	8744 examples of class 1
# 	8744 examples of class 2

# %% [markdown]
# # Training

# %% [markdown]
# Select Hyper-parameters

# %%
from cvnn.layers import Dense
from cvnn import layers


shape_raw = [100, 50]
input_size = dataset.x.shape[1]  # Size of input
output_size = dataset.y.shape[1]  # Size of output
layers.ComplexLayer.last_layer_output_dtype = None
layers.ComplexLayer.last_layer_output_size = None
if len(shape_raw) == 0:
    print("No hidden layers are used. activation and dropout will be ignored")
    shape = [
        Dense(input_size=input_size, output_size=output_size, activation='softmax_real',
              input_dtype=np.complex64, dropout=None)
    ]
else:  # len(shape_raw) > 0:
    shape = [Dense(input_size=input_size, output_size=shape_raw[0], activation='cart_relu',
                   input_dtype=np.complex64, dropout=0.5)]
    for i in range(1, len(shape_raw)):
        shape.append(Dense(output_size=shape_raw[i], activation='cart_relu', dropout=0.5))
    shape.append(Dense(output_size=output_size, activation='softmax_real', dropout=None))

# %%
from cvnn.cvnn_model import CvnnModel
from tensorflow.keras.losses import categorical_crossentropy

complex_network = CvnnModel(name="complex_network", shape=shape, loss_fun=categorical_crossentropy, optimizer='sgd', verbose=False, tensorboard=False)
complex_network.fit(dataset.x, dataset.y, validation_data = (x_val.astype(np.complex64), y_val), epochs = 300, batch_size=100, verbose=2, save_csv_history=True)
# Out:
# Epoch 1/300
#    1050/Unknown - 1s 1ms/step - loss: 0.2416 - accuracy: 0.9000 - val_loss: 0.2906 - val_accuracy: 0.8933
# Epoch 2/300
# 1050/1050 [==============================] - 1s 825us/step - loss: 0.2500 - accuracy: 0.8800 - val_loss: 0.2911 - val_accuracy: 0.8954
# Epoch 3/300
# 1050/1050 [==============================] - 1s 814us/step - loss: 0.2965 - accuracy: 0.8600 - val_loss: 0.2974 - val_accuracy: 0.8936
# Epoch 4/300
# 1050/1050 [==============================] - 1s 809us/step - loss: 0.3477 - accuracy: 0.9100 - val_loss: 0.2888 - val_accuracy: 0.8970
# Epoch 5/300
# 1050/1050 [==============================] - 1s 823us/step - loss: 0.2207 - accuracy: 0.9200 - val_loss: 0.2889 - val_accuracy: 0.8955
# Epoch 6/300
# 1050/1050 [==============================] - 1s 813us/step - loss: 0.3321 - accuracy: 0.8500 - val_loss: 0.2879 - val_accuracy: 0.8969
# Epoch 7/300
# 1050/1050 [==============================] - 1s 862us/step - loss: 0.2804 - accuracy: 0.9100 - val_loss: 0.2907 - val_accuracy: 0.8953
# Epoch 8/300
# 1050/1050 [==============================] - 1s 830us/step - loss: 0.2704 - accuracy: 0.8700 - val_loss: 0.2882 - val_accuracy: 0.8952
# Epoch 9/300
# 1050/1050 [==============================] - 1s 830us/step - loss: 0.3855 - accuracy: 0.8800 - val_loss: 0.3991 - val_accuracy: 0.8358
# Epoch 10/300
# 1050/1050 [==============================] - 1s 831us/step - loss: 0.1974 - accuracy: 0.9600 - val_loss: 0.2828 - val_accuracy: 0.8985
# Epoch 11/300
# 1050/1050 [==============================] - 1s 813us/step - loss: 0.2824 - accuracy: 0.9400 - val_loss: 0.2876 - val_accuracy: 0.8987
# Epoch 12/300
# 1050/1050 [==============================] - 1s 826us/step - loss: 0.2464 - accuracy: 0.9100 - val_loss: 0.2856 - val_accuracy: 0.8963
# Epoch 13/300
# 1050/1050 [==============================] - 1s 822us/step - loss: 0.2639 - accuracy: 0.9000 - val_loss: 0.3032 - val_accuracy: 0.8934
# Epoch 14/300
# 1050/1050 [==============================] - 1s 846us/step - loss: 0.2455 - accuracy: 0.8700 - val_loss: 0.3029 - val_accuracy: 0.8901
# Epoch 15/300
# 1050/1050 [==============================] - 1s 889us/step - loss: 0.2519 - accuracy: 0.9300 - val_loss: 0.2856 - val_accuracy: 0.8974
# Epoch 16/300
# 1050/1050 [==============================] - 1s 827us/step - loss: 0.3195 - accuracy: 0.8900 - val_loss: 0.2833 - val_accuracy: 0.8961
# Epoch 17/300
# 1050/1050 [==============================] - 1s 840us/step - loss: 0.2550 - accuracy: 0.9300 - val_loss: 0.2888 - val_accuracy: 0.8985
# Epoch 18/300
300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2555 - accuracy: 0.9000 - val_loss: 0.2694 - val_accuracy: 0.9041
# Epoch 214/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1780 - accuracy: 0.9000 - val_loss: 0.2644 - val_accuracy: 0.9060
# Epoch 215/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1851 - accuracy: 0.9400 - val_loss: 0.2681 - val_accuracy: 0.9056
# Epoch 216/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2141 - accuracy: 0.9300 - val_loss: 0.2694 - val_accuracy: 0.9040
# Epoch 217/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3553 - accuracy: 0.8800 - val_loss: 0.2647 - val_accuracy: 0.9037
# Epoch 218/300
# 1050/1050 [==============================] - 1s 993us/step - loss: 0.2462 - accuracy: 0.8800 - val_loss: 0.2748 - val_accuracy: 0.9028
# Epoch 219/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3078 - accuracy: 0.9100 - val_loss: 0.2681 - val_accuracy: 0.9039
# Epoch 220/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3497 - accuracy: 0.8700 - val_loss: 0.2803 - val_accuracy: 0.9005
# Epoch 221/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3810 - accuracy: 0.8700 - val_loss: 0.2668 - val_accuracy: 0.9012
# Epoch 222/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1473 - accuracy: 0.9200 - val_loss: 0.2741 - val_accuracy: 0.9022
# Epoch 223/300
# 1050/1050 [==============================] - 1s 979us/step - loss: 0.2226 - accuracy: 0.9000 - val_loss: 0.2668 - val_accuracy: 0.9058
# Epoch 224/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2171 - accuracy: 0.9100 - val_loss: 0.2650 - val_accuracy: 0.9034
# Epoch 225/300
# 1050/1050 [==============================] - 1s 973us/step - loss: 0.3083 - accuracy: 0.9000 - val_loss: 0.2732 - val_accuracy: 0.9045
# Epoch 226/300
# 1050/1050 [==============================] - 1s 979us/step - loss: 0.2929 - accuracy: 0.8900 - val_loss: 0.2721 - val_accuracy: 0.9017
# Epoch 227/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1926 - accuracy: 0.9300 - val_loss: 0.2651 - val_accuracy: 0.9044
# Epoch 228/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2113 - accuracy: 0.9300 - val_loss: 0.2668 - val_accuracy: 0.9035
# Epoch 229/300
# 1050/1050 [==============================] - 1s 988us/step - loss: 0.3187 - accuracy: 0.8900 - val_loss: 0.2662 - val_accuracy: 0.9031
# Epoch 230/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2620 - accuracy: 0.9200 - val_loss: 0.2692 - val_accuracy: 0.9055
# Epoch 231/300
# 1050/1050 [==============================] - 1s 977us/step - loss: 0.2227 - accuracy: 0.8900 - val_loss: 0.2664 - val_accuracy: 0.9020
# Epoch 232/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3709 - accuracy: 0.8900 - val_loss: 0.2712 - val_accuracy: 0.8981
# Epoch 233/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1805 - accuracy: 0.9300 - val_loss: 0.2734 - val_accuracy: 0.9015
# Epoch 234/300
# 1050/1050 [==============================] - 1s 990us/step - loss: 0.1759 - accuracy: 0.9300 - val_loss: 0.2636 - val_accuracy: 0.9042
# Epoch 235/300
# 1050/1050 [==============================] - 1s 999us/step - loss: 0.3130 - accuracy: 0.9200 - val_loss: 0.2696 - val_accuracy: 0.9031
# Epoch 236/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1898 - accuracy: 0.9500 - val_loss: 0.2650 - val_accuracy: 0.9053
# Epoch 237/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2516 - accuracy: 0.8700 - val_loss: 0.2636 - val_accuracy: 0.9037
# Epoch 238/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1945 - accuracy: 0.9400 - val_loss: 0.2694 - val_accuracy: 0.9017
# Epoch 239/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3078 - accuracy: 0.8900 - val_loss: 0.2689 - val_accuracy: 0.9004
# Epoch 240/300
# 1050/1050 [==============================] - 1s 1000us/step - loss: 0.2826 - accuracy: 0.8900 - val_loss: 0.3016 - val_accuracy: 0.8891
# Epoch 241/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1940 - accuracy: 0.9200 - val_loss: 0.2647 - val_accuracy: 0.9028
# Epoch 242/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2687 - accuracy: 0.9100 - val_loss: 0.2605 - val_accuracy: 0.9055
# Epoch 243/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2524 - accuracy: 0.9100 - val_loss: 0.2609 - val_accuracy: 0.9052
# Epoch 244/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2643 - accuracy: 0.9100 - val_loss: 0.2608 - val_accuracy: 0.9060
# Epoch 245/300
# 1050/1050 [==============================] - 1s 997us/step - loss: 0.2523 - accuracy: 0.8700 - val_loss: 0.2789 - val_accuracy: 0.9000
# Epoch 246/300
# 1050/1050 [==============================] - 1s 1000us/step - loss: 0.2582 - accuracy: 0.9100 - val_loss: 0.2844 - val_accuracy: 0.8988
# Epoch 247/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2399 - accuracy: 0.9100 - val_loss: 0.2705 - val_accuracy: 0.9028
# Epoch 248/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3416 - accuracy: 0.9100 - val_loss: 0.2650 - val_accuracy: 0.9066
# Epoch 249/300
# 1050/1050 [==============================] - 1s 993us/step - loss: 0.2377 - accuracy: 0.8900 - val_loss: 0.2614 - val_accuracy: 0.9065
# Epoch 250/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2009 - accuracy: 0.9300 - val_loss: 0.2617 - val_accuracy: 0.9045
# Epoch 251/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2224 - accuracy: 0.8800 - val_loss: 0.2947 - val_accuracy: 0.8943
# Epoch 252/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2552 - accuracy: 0.9000 - val_loss: 0.2678 - val_accuracy: 0.9037
# Epoch 253/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3399 - accuracy: 0.8600 - val_loss: 0.2807 - val_accuracy: 0.9000
# Epoch 254/300
# 1050/1050 [==============================] - 1s 997us/step - loss: 0.2883 - accuracy: 0.8800 - val_loss: 0.2809 - val_accuracy: 0.8991
# Epoch 255/300
# 1050/1050 [==============================] - 1s 1000us/step - loss: 0.1838 - accuracy: 0.9500 - val_loss: 0.2623 - val_accuracy: 0.9044
# Epoch 256/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2272 - accuracy: 0.9200 - val_loss: 0.2731 - val_accuracy: 0.9034
# Epoch 257/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2629 - accuracy: 0.9200 - val_loss: 0.2616 - val_accuracy: 0.9046
# Epoch 258/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3142 - accuracy: 0.8900 - val_loss: 0.2641 - val_accuracy: 0.9039
# Epoch 259/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2734 - accuracy: 0.8400 - val_loss: 0.2831 - val_accuracy: 0.8980
# Epoch 260/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2439 - accuracy: 0.9200 - val_loss: 0.2673 - val_accuracy: 0.9023
# Epoch 261/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2933 - accuracy: 0.8600 - val_loss: 0.2752 - val_accuracy: 0.9028
# Epoch 262/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2934 - accuracy: 0.9100 - val_loss: 0.2683 - val_accuracy: 0.9022
# Epoch 263/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1814 - accuracy: 0.9400 - val_loss: 0.2620 - val_accuracy: 0.9059
# Epoch 264/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3583 - accuracy: 0.8600 - val_loss: 0.2730 - val_accuracy: 0.9006
# Epoch 265/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2702 - accuracy: 0.9000 - val_loss: 0.2717 - val_accuracy: 0.9024
# Epoch 266/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1468 - accuracy: 0.9600 - val_loss: 0.2657 - val_accuracy: 0.9040
# Epoch 267/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1523 - accuracy: 0.9600 - val_loss: 0.2641 - val_accuracy: 0.9061
# Epoch 268/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2593 - accuracy: 0.9100 - val_loss: 0.2809 - val_accuracy: 0.8992
# Epoch 269/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1125 - accuracy: 0.9900 - val_loss: 0.2561 - val_accuracy: 0.9058
# Epoch 270/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2534 - accuracy: 0.9300 - val_loss: 0.2630 - val_accuracy: 0.9097
# Epoch 271/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2967 - accuracy: 0.9200 - val_loss: 0.2850 - val_accuracy: 0.9002
# Epoch 272/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1586 - accuracy: 0.9400 - val_loss: 0.2658 - val_accuracy: 0.9028
# Epoch 273/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2040 - accuracy: 0.9400 - val_loss: 0.2758 - val_accuracy: 0.9013
# Epoch 274/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1715 - accuracy: 0.9400 - val_loss: 0.2606 - val_accuracy: 0.9056
# Epoch 275/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1698 - accuracy: 0.9400 - val_loss: 0.2644 - val_accuracy: 0.9039
# Epoch 276/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1420 - accuracy: 0.9500 - val_loss: 0.2651 - val_accuracy: 0.9072
# Epoch 277/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3149 - accuracy: 0.8300 - val_loss: 0.2879 - val_accuracy: 0.8952
# Epoch 278/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2515 - accuracy: 0.9100 - val_loss: 0.2628 - val_accuracy: 0.9057
# Epoch 279/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2157 - accuracy: 0.9300 - val_loss: 0.2641 - val_accuracy: 0.9040
# Epoch 280/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1819 - accuracy: 0.9400 - val_loss: 0.2652 - val_accuracy: 0.9047
# Epoch 281/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1903 - accuracy: 0.9300 - val_loss: 0.2642 - val_accuracy: 0.9030
# Epoch 282/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1942 - accuracy: 0.9200 - val_loss: 0.2790 - val_accuracy: 0.9001
# Epoch 283/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2561 - accuracy: 0.9000 - val_loss: 0.2672 - val_accuracy: 0.9026
# Epoch 284/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3310 - accuracy: 0.8600 - val_loss: 0.2763 - val_accuracy: 0.9045
# Epoch 285/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2681 - accuracy: 0.9100 - val_loss: 0.2911 - val_accuracy: 0.8962
# Epoch 286/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2142 - accuracy: 0.9500 - val_loss: 0.2617 - val_accuracy: 0.9063
# Epoch 287/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3303 - accuracy: 0.9000 - val_loss: 0.2659 - val_accuracy: 0.9079
# Epoch 288/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2563 - accuracy: 0.9300 - val_loss: 0.2620 - val_accuracy: 0.9037
# Epoch 289/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2679 - accuracy: 0.9200 - val_loss: 0.2619 - val_accuracy: 0.9071
# Epoch 290/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1977 - accuracy: 0.9200 - val_loss: 0.2658 - val_accuracy: 0.9046
# Epoch 291/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2371 - accuracy: 0.9200 - val_loss: 0.2850 - val_accuracy: 0.9006
# Epoch 292/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.1783 - accuracy: 0.9500 - val_loss: 0.2642 - val_accuracy: 0.9035
# Epoch 293/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2641 - accuracy: 0.8900 - val_loss: 0.2576 - val_accuracy: 0.9062
# Epoch 294/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2461 - accuracy: 0.8800 - val_loss: 0.2724 - val_accuracy: 0.9020
# Epoch 295/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2652 - accuracy: 0.8900 - val_loss: 0.2611 - val_accuracy: 0.9053
# Epoch 296/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2013 - accuracy: 0.9400 - val_loss: 0.2616 - val_accuracy: 0.9068
# Epoch 297/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3291 - accuracy: 0.9100 - val_loss: 0.2635 - val_accuracy: 0.9025
# Epoch 298/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2230 - accuracy: 0.9200 - val_loss: 0.2663 - val_accuracy: 0.9071
# Epoch 299/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.2678 - accuracy: 0.8700 - val_loss: 0.3239 - val_accuracy: 0.8903
# Epoch 300/300
# 1050/1050 [==============================] - 1s 1ms/step - loss: 0.3005 - accuracy: 0.8800 - val_loss: 0.2667 - val_accuracy: 0.9052

# %% [markdown]
# # See results

# %%
prediction = complex_network.predict(T.astype(np.complex64)).numpy()
prediction.shape
# Out:
# (1311618,)

# %%
prediction_image = np.zeros(raw_labels.shape, dtype=int)
p_index = 0
for i in range(raw_labels.shape[0]):
    for j in range(raw_labels.shape[1]):
        if raw_labels[i, j] != 0:
            prediction_image[i, j] = prediction[p_index] + 1
            p_index += 1
assert p_index == len(prediction)

# %%
show_ground_truth(prediction_image, "./complex_result")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3c4f3c1ad610> in <module>
# ----> 1 show_ground_truth(prediction_image, "./complex_result")
#
# <ipython-input-14-d9833e06efe4> in show_ground_truth(labels, savefile)
#      17     if savefile is not None:
#      18         savefile = Path(savefile)
# ---> 19         plt.imsave(savefile + ".pdf", ground_truth)
#      20         tikzplotlib.save(savefile + ".tex")
#      21
#
# TypeError: unsupported operand type(s) for +: 'PosixPath' and 'str'

# %%
loss, acc = complex_network.evaluate(x_test.astype(np.complex64), y_test)
print("Test Accuracy: {0:.2%}; Loss: {1:.4}".format(acc, loss))

# %%
complex_network.get_confusion_matrix(x_test.astype(np.complex64), y_test)

# %% [markdown]
# ## Real Network

# %%
from cvnn.utils import transform_to_real

real_network = complex_network.get_real_equivalent()
x_fit = transform_to_real(dataset.x)
real_network.fit(x_fit, dataset.y, validation_data = (x_val.astype(np.complex64), y_val), epochs = 300, batch_size=100, verbose=2, save_csv_history=True)

# %%
T_real = transform_to_real(T.astype(np.complex64))
prediction = real_network.predict(T_real).numpy()
prediction_image = np.zeros(raw_labels.shape, dtype=int)
p_index = 0
for i in range(raw_labels.shape[0]):
    for j in range(raw_labels.shape[1]):
        if raw_labels[i, j] != 0:
            prediction_image[i, j] = prediction[p_index] + 1
            p_index += 1
assert p_index == len(prediction)

# %%
show_ground_truth(prediction_image, "./real_result")

# %%
loss, acc = real_network.evaluate(x_test.astype(np.complex64), y_test)
print("Test Accuracy: {0:.2%}; Loss: {1:.4}".format(acc, loss))

# %%
real_network.get_confusion_matrix(x_test.astype(np.complex64), y_test)
